# %% [markdown]
# # Abrimos el archivo.

# %%
import pandas as pd
data = pd.read_csv('/home/ivan/PycharmProjects/pp_354/p05/heart_20x12.csv', engine='python')

# %% [markdown]
# # Mostramos las 5 primeras filas

# %%
data.head()
# Out:
#       id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0  20995  19521       2     164      74    120     60            2     1
# 1  42736  21327       1     164      63    120     80            1     1
# 2  38230  19585       2     170      50    110     70            1     1
# 3   7498  18782       1     152      52    180   1000            1     1
# 4  83833  16287       1     168      98    120     80            1     1
#
#    smoke  alco  active cardio
# 0      1     1       1     Si
# 1      0     0       1     No
# 2      0     0       1     Si
# 3      0     0       1     Si
# 4      0     0       1     No

# %% [markdown]
# # Generamos 4 Numeros aleatorios

# %%
import random
aleatorios=random.sample(range(1,11),4)
# Variables predictoras
a=aleatorios[0]
b=aleatorios[1]
c=aleatorios[2]
d=aleatorios[3]
print(a,b,c,d)
# Out:
# 6 3 7 10

# %% [markdown]
# # Variables predictoras con columnas aleatorias.

# %%
X=data.iloc[:,[a,b,c,d]]
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ap_lo        21 non-null     int64
#  1   height       21 non-null     int64
#  2   cholesterol  21 non-null     int64
#  3   alco         21 non-null     int64
# dtypes: int64(4)
# memory usage: 800.0 bytes

# %% [markdown]
# # variable a predecir

# %%
Y=data.iloc[:,12]

# %% [markdown]
# # Importamos las librerias para el graficar el arbol

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = 0.8, random_state = 0)

# %%
arbol = DecisionTreeClassifier(max_depth=4)

# %%
arbol_diabetes = arbol.fit(X_train,Y_train)

# %% [markdown]
# # Graficamos el arbol de decision.

# %%
plt.figure("Arbol de decision",figsize=[12,8])
plot_tree(arbol,fontsize=10, filled=True, feature_names=list(X.columns.values),class_names = list(Y.values))
plt.show()
